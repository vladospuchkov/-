# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Клонирование в «yolov5»...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Получение объектов: 100% (16575/16575), 15.09 МиБ | 977.00 КиБ/с, готово.
# Определение изменений: 100% (11381/11381), готово.

# %%
import torch
print(torch.cuda.is_available())
torch.cuda.empty_cache()
# Out:
# True

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/train.py --data /home/vladislave/coding/ii/2.1/car/data.yaml --weights yolov5s.pt \
--hyp /home/vladislave/coding/ii/2.1/yolov5/data/hyps/my_hyp.yaml\
--epochs 80 --batch-size 32 --optimizer SGD --name popitka --workers 4
# Out:
# train: weights=yolov5s.pt, cfg=, data=/home/vladislave/coding/ii/2.1/car/data.yaml, hyp=/home/vladislave/coding/ii/2.1/yolov5/data/hyps/my_hyp.yaml, epochs=80, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=yolov5/data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=4, project=yolov5/runs/train, name=popitka, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# ...

# %% [markdown]
# +++

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/detect.py --source 'https://er.ru/media/news/February2021/VGJhQGcMtuFu2PaItQIV.jpg' --weights '/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka3/weights/best.pt' --img 1280 682 --save-txt --save-crop
# Out:
# detect: weights=['/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka3/weights/best.pt'], source=https://er.ru/media/news/February2021/VGJhQGcMtuFu2PaItQIV.jpg, data=yolov5/data/coco128.yaml, imgsz=[896, 896], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# ...
# 100%|████████████████████████████████████████| 172k/172k [00:00<00:00, 1.14MB/s]
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /home/vladislave/coding/ii/2.1/VGJhQGcMtuFu2PaItQIV.jpg: 512x896 3 cars, 64.1ms
# ...

# %% [markdown]
# ++-

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/detect.py --source 'https://motor.ru/thumb/1500x0/filters:quality(75):no_upscale()/imgs/2022/01/27/11/5197968/f7aba1d92862152a77a6fcf637d2ea171e1defe8.jpg' --weights '/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt' --img 896 --save-txt --save-crop
# Out:
# detect: weights=['/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt'], source=https://motor.ru/thumb/1500x0/filters:quality(75):no_upscale()/imgs/2022/01/27/11/5197968/f7aba1d92862152a77a6fcf637d2ea171e1defe8.jpg, data=yolov5/data/coco128.yaml, imgsz=[896, 896], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# Found https://motor.ru/thumb/1500x0/filters:quality(75):no_upscale()/imgs/2022/01/27/11/5197968/f7aba1d92862152a77a6fcf637d2ea171e1defe8.jpg locally at f7aba1d92862152a77a6fcf637d2ea171e1defe8.jpg
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# Fusing layers...
# ...

# %% [markdown]
# +++

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/detect.py --source 'https://img.gazeta.ru/files3/225/15619225/602fd8501fa16_img-pic_32ratio_1200x800-1200x800-70042.jpg' --weights '/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt' --img 896 --save-txt --save-crop
# Out:
# detect: weights=['/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt'], source=https://img.gazeta.ru/files3/225/15619225/602fd8501fa16_img-pic_32ratio_1200x800-1200x800-70042.jpg, data=yolov5/data/coco128.yaml, imgsz=[896, 896], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# Found https://img.gazeta.ru/files3/225/15619225/602fd8501fa16_img-pic_32ratio_1200x800-1200x800-70042.jpg locally at 602fd8501fa16_img-pic_32ratio_1200x800-1200x800-70042.jpg
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# Fusing layers...
# ...

# %% [markdown]
# медведь

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/detect.py --source 'https://cdn.iz.ru/sites/default/files/article-2021-07/RIAN_5874336.HR_.ru_.jpg' --weights '/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt' --img 896 --save-txt --save-crop
# Out:
# detect: weights=['/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt'], source=https://cdn.iz.ru/sites/default/files/article-2021-07/RIAN_5874336.HR_.ru_.jpg, data=yolov5/data/coco128.yaml, imgsz=[896, 896], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# Found https://cdn.iz.ru/sites/default/files/article-2021-07/RIAN_5874336.HR_.ru_.jpg locally at RIAN_5874336.HR_.ru_.jpg
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# ...

# %%
# !python3.10 /home/vladislave/coding/ii/2.1/yolov5/detect.py --source '/home/vladislave/coding/ii/2.1/vdeoinput.mp4' --weights '/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt' --img 896 --save-txt --save-crop
# Out:
# detect: weights=['/home/vladislave/coding/ii/2.1/yolov5/runs/train/popitka2/weights/last.pt'], source=/home/vladislave/coding/ii/2.1/vdeoinput.mp4, data=yolov5/data/coco128.yaml, imgsz=[896, 896], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2602) /home/vladislave/coding/ii/2.1/vdeoinput.mp4: 512x896 (no detections), 61.9ms
# video 1/1 (2/2602) /home/vladislave/coding/ii/2.1/vdeoinput.mp4: 512x896 (no detections), 5.3ms
# ...
